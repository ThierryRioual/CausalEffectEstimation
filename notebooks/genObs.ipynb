# %% [markdown]
# # ATE estimations from generated observational data
# *This notebook examines the use of Bayesian Networks for estimating Average Treatment Effects (ATE) in Observational Studies within the Neyman-Rubin potential outcome framework from generated data:* [Lunceford & Davidian (2004)]("https://pubmed.ncbi.nlm.nih.gov/15351954/")

# %% [markdown]
# ### Context
#
# In contrast to randomized controlled trials (RCTs) where the ignorability assumption is satisfied, estimating treatment effects from observational data introduces new complexities.
#
# Under RCT conditions, an unbiased estimator of the Average Treatment Effect (ATE) can be effectively computed by comparing the means of the observed treated subjects and the observed untreated subjects.
# However, in observational data, the ignorability assumption often does not hold, as subjects with certain treatment outcomes may be more or less likely to receive the treatment (i.e. $ \mathbb{E}[Y(t)|T=t] \neq \mathbb{E}[Y(t)], \ t \in \{0,1\}$). Consequently, previous estmation methods are not guaranteed to be unbiased.
#
# Nevertheless, if we can identify the confounders that *d-separates* the potential outcomes from the treatement assignment, we can achieve conditional independence between the treatment and the outcomes by conditionning on the confounders. Suppose that the covariate vector contains all such confounders, then:
#
# $$\begin{align*}
# T \perp \!\!\! \perp \{ Y(0), Y(1)\} \mid X & \quad \mathrm{(Unconfoundedness)}
# \end{align*}$$
#
# This conditional independence allows for estimations of the ATE from observational data.

# %%
import pyAgrum as gum
import pyAgrum.lib.notebook as gnb
import pyAgrum.skbn as skbn

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from scipy.stats import norm, logistic

# %% [markdown]
# ### Generated Data
#
# * The *outcome* variable $Y$ is generated according the following equation:
# $$ \begin{align*}
# Y & = - X_1 + X_2 - X_3 +2 T -V_1 + V_2 + V_3 \\
#   & = \langle \nu , \boldsymbol{Z} \rangle + \langle \xi, \boldsymbol{V} \rangle
# \end{align*}$$
#
# Where $\nu = (0, -1, 1, -1, 2)^\intercal$, $\boldsymbol{Z} = (1, X_1, X_2, X_3, T)^\intercal$, $\xi = (-1,1,1)^\intercal$ and $\boldsymbol{V} = (V_1, V_2, V_3)^\intercal$.
#
# * The *covariates* are distributed as $X_3 \sim \text{Bernoulli}\left(0.2\right)$. Conditionally $X_3$, the distribution of the other variables is defined as:
#
# If $X_{3} = 0$, $V_3 \sim \text{Bernoulli}\left(0.25\right)$ and
#  ${\left(X_{1}, V_{1}, X_{2}, V_{2}\right)}^{\intercal} \sim \mathcal{N}_4({\tau}_{0}, \Sigma)$
#
# If $ X_{3} = 1$, $V_3 \sim  \text{Bernoulli}\left(0.75\right)$ and ${\left(X_{1}, V_{1}, X_{2}, V_{2}\right)}^{\intercal} \sim \mathcal{N}_4({\tau}_{1}, \Sigma)$
# with
# $$ {\tau}_{1} = \left(\begin{array}{c}
# 1 \\
# 1 \\
# -1\\
# -1
# \end{array}\right), {\tau}_{0} = \left(\begin{array}{c}
# -1 \\
# -1 \\
# 1\\
# 1
# \end{array}\right) \ \text{and} \ \Sigma = \left(\begin{array}{cccc}
# 1 & 0.5 & -0.5 & -0.5\\
# 0.5 & 1 & -0.5 & -0.5  \\
# -0.5 & -0.5 & 1 & 0.5 \\
# -0.5 & -0.5 & 0.5 & 1
# \end{array}
# \right)$$
#
# * The *treatment* $T$ is generated as a Bernoulli of the *propensity score*:
# $$ \begin{align*}
# \mathbb{P}[T=1|X] &= e\left(X, \beta\right) \\
# &= (1+\exp (-0.6 X_{1} +0.6 X_{2} - 0.6 X_{3}))^{-1} \\
# &= \frac{1}{1+e^{-\langle \beta , \boldsymbol{X} \rangle}} \\
# \mathbb{P}[T=0|X] &= 1-\mathbb{P}[T=1|X]
# \end{align*}$$
# With $\beta = {\left(0, 0.6, -0.6, 0.6\right)}^{\intercal}$ and $\boldsymbol{X} = (1, X_1, X_2, X_3)^{\intercal}$.

# %%
# Model parameters
XI = np.array([-1, 1, 1])
NU = np.array([0, -1, 1, -1, 2])
BETA = np.array([0, 0.6, -0.6, 0.6])
TAU_0 = np.array([-1, -1, 1, 1])
TAU_1 = TAU_0 * -1
SIGMA = np.array([[1, 0.5, -0.5, -0.5],
                  [0.5, 1, -0.5, -0.5],
                  [-0.5, -0.5, 1, 0.5],
                  [-0.5, -0.5, 0.5, 1]], dtype=float)

def generate_lunceford(n=1000):
    # Generate data
    x3 = np.random.binomial(1, 0.2, n)
    v3 = np.random.binomial(1, (0.75 * x3 + (0.25 * (1 - x3))), n)

    # If x3=0 you have a model, if x3=1 you have another one
    x1v1x2v2_x3_0_matrix = np.random.multivariate_normal(TAU_0, SIGMA, size=n, check_valid='warn', tol=1e-8)
    x1v1x2v2_x3_1_matrix = np.random.multivariate_normal(TAU_1, SIGMA, size=n, check_valid='warn', tol=1e-8)
    x1v1x2v2_x3 = np.where(np.repeat(x3[:, np.newaxis], 4, axis=1) == 0, x1v1x2v2_x3_0_matrix, x1v1x2v2_x3_1_matrix)

    # Concatenate values
    xv = np.concatenate([x1v1x2v2_x3, np.expand_dims(x3, axis=1), np.expand_dims(v3, axis=1)], axis=1)

    # Compute e, a, and y
    x = xv[:, [0,2,4]]
    v = xv[:, [1,3,5]]
    e = np.power(1 + np.exp(- BETA[0] - x.dot(BETA[1:])), -1)
    a = np.random.binomial(1, e, n)
    y = x.dot(NU[1:-1]) + v.dot(XI) + a*NU[-1] + np.random.binomial(1, e, n) + np.random.normal(0, 1, n)

    # Create the final df
    synthetic_data_df = pd.DataFrame(np.concatenate([x, np.expand_dims(a, axis=1), v, np.expand_dims(y, axis=1)], axis=1), columns=["X1", "X2", "X3", "T", "V1", "V2", "V3", "Y"])
    synthetic_data_df["X3"] = synthetic_data_df["X3"].astype(int)
    synthetic_data_df["V3"] = synthetic_data_df["V3"].astype(int)
    synthetic_data_df["T"] = synthetic_data_df["T"].astype(int)

    return synthetic_data_df

# %% [markdown]
# Here, the exact ATE can be explicitly calculated using the previously defined assumptions.
#
# $$ \begin{align*}
# \mathbb{E}[Y(1) - Y(0)] &= \mathbb{E} [ (- X_1 + X_2 - X_3 + 2 \times 1 -V_1 + V_2 + V_3) - (- X_1 + X_2 - X_3 + 2 \times 0 -V_1 + V_2 + V_3 ) ] \\
# &= 2
# \end{align*} $$

# %%
df = generate_lunceford(int(1e6))
df.head()
# Out:
#          X1        X2  X3  T        V1        V2  V3         Y
# 0  0.464229 -0.430723   0  1  0.099841 -1.011027   0  0.075322
# 1 -1.150273 -0.266724   0  0 -2.428685  0.263078   0  4.929957
# 2 -1.468083  2.036699   0  1 -0.352060  1.520255   1  8.581494
# 3 -0.466710  0.906196   0  1 -1.431502  0.897375   1  5.796999
# 4  0.555739 -0.323768   1  0  1.226500 -0.554684   1 -4.098917

# %% [markdown]
# ### 1 - "Exact" Computation

# %%
# Declarations of functions used in this section

def getBN(# Covariate parameters
          covariate_start : int = -5.0,
          covariate_end : int = 5.0 ,
          covariate_num_split : int = 10,
          # Outcome parameters
          outcome_start = -10.0 ,
          outcome_end = 15.0 ,
          outcome_num_split = 60,
          # Other
          data : pd.DataFrame | None = None,
          add_arcs : bool = True,
          fill_distribution : bool = True) -> gum.BayesNet:
    """
    Returns Baysian Network corresponding to the model by discretising
    countinous variables with given parameters.
    """
    if data is None:
        plus = "" if fill_distribution else "+"
        bn = gum.BayesNet()
        for i in range(1,3):
            bn.add(f"X{i}{plus}[{covariate_start}:{covariate_end}:{covariate_num_split}]")
            bn.add(f"V{i}{plus}[{covariate_start}:{covariate_end}:{covariate_num_split}]")
        bn.add(f"X3[2]")
        bn.add(f"V3[2]")
        bn.add("T[2]")
        bn.add(f"Y{plus}[{outcome_start}:{outcome_end}:{outcome_num_split}]")

    else :
        disc = skbn.BNDiscretizer(defaultDiscretizationMethod="uniform",
                                  defaultNumberOfBins=covariate_num_split)
        disc.setDiscretizationParameters("Y", 'uniform', outcome_num_split)
        bn = disc.discretizedBN(data)

    if add_arcs :
        bn.beginTopologyTransformation()
        for _, name in bn:
            if name != "Y":
                bn.addArc(name, "Y")
        for X in ["X1", "X2", "X3"]:
            bn.addArc(X, "T")
        for XV in ["X1", "V1", "X2", "V2"]:
            bn.addArc("X3", XV)
        bn.addArc("X3", "V3")
        bn.endTopologyTransformation()

    if add_arcs and fill_distribution:
        bn.cpt("X3").fillWith([0.8, 0.2])
        bn.cpt("V3")[:] = [[0.75, 0.25], [0.25, 0.75]]
        for XV in ["X", "V"]:
            bn.cpt(f"{XV}1").fillFromDistribution(norm, loc="2*X3-1", scale=1)
            bn.cpt(f"{XV}2").fillFromDistribution(norm, loc="1-2*X3", scale=1)
        bn.cpt("T").fillFromDistribution(logistic, loc="-0.6*X1+0.6*X2-0.6*X3", scale=1)
        bn.cpt("Y").fillFromDistribution(norm, loc="-X1+X2-X3+2*T-V1+V2+V3", scale=1)

    return bn

def mutilateBN(bn : gum.BayesNet) -> gum.BayesNet:
    """
    Returns a copy of the Bayesian Network with all incoming arcs to the variable T removed.
    """
    res = gum.BayesNet(bn)
    for p_id in bn.parents("T"):
        res.eraseArc(p_id, bn.idFromName("T"))
    return res

def ATE(bn : gum.BayesNet) -> float:
    """
    Returns estimation of the ATE directly from Baysian Network.
    """

    ie = gum.LazyPropagation(mutilateBN(bn))

    ie.setEvidence({"T": 0})
    ie.makeInference()
    p0 = ie.posterior("Y")

    ie.chgEvidence("T",1)
    ie.makeInference()
    p1 = ie.posterior("Y")

    dif = p1 - p0
    return dif.expectedValue(lambda d: dif.variable(0).numerical(d[dif.variable(0).name()]))

# %%
exbn = getBN(covariate_num_split=5, outcome_num_split=100)
gnb.showBN(exbn, size="50")

# %%
gnb.sideBySide(gnb.getInference(mutilateBN(exbn), evs={"T":0}, targets={"Y"}),
               gnb.getInference(mutilateBN(exbn), evs={"T":1}, targets={"Y"}),
               captions=["T=0", "T=1"])

print(exbn)
print(f"{ATE(exbn) = }")
# Out:
# <table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="550pt" height="258pt" viewBox="0.00 0.00 550.00 258.00">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 254)">
# <title>structs</title>
# <text text-anchor="middle" x="271" y="-7.8" font-family="Times,serif" font-size="14.00" fill="#4a4a4a">Inference in   3.46ms</text>
# <!-- X1 -->
# <g id="node1" class="node">
# <title>X1</title>
# <ellipse fill="#404040" stroke="#000000" cx="55" cy="-160" rx="27" ry="18"/>
# <text text-anchor="middle" x="55" y="-157.5" font-family="DejaVu Sans" font-size="10.00" fill="white">X1</text>
# </g>
# <!-- Y -->
# <g id="node8" class="node">
# <title>Y</title>
# <polygon fill="#e0e0e0" stroke="#000000" points="542,-106 0,-106 0,-23 542,-23 542,-106"/>
# <svg viewBox="0 0 720.628125 107.873625" width="542px" height="83px" preserveAspectRatio="xMinYMin meet" x="0" y="-106"> <metadata>
#   <rdf:RDF xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:cc="http://creativecommons.org/ns#" xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#">
#    <cc:Work>
#     <dc:type rdf:resource="http://purl.org/dc/dcmitype/StillImage"/>
#     <dc:date>2024-08-13T14:31:28.091397</dc:date>
#     <dc:format>image/svg+xml</dc:format>
#     <dc:creator>
#      <cc:Agent>
#       <dc:title>Matplotlib v3.5.1, https://matplotlib.org/</dc:title>
#      </cc:Agent>
#     </dc:creator>
#    </cc:Work>
#   </rdf:RDF>
#  </metadata>
#  <defs>
#   <style type="text/css">*{stroke-linejoin: round; stroke-linecap: butt}</style>
#  </defs>
#  <g id="figure_1">
#   <g id="patch_1">
#    <path d="M 0 107.873625  L 720.628125 107.873625  L 720.628125 0  L 0 0  z " style="fill: #e0e0e0"/>
#   </g>
#   <g id="axes_1">
#    <g id="patch_2">
#     <path d="M 26.503125 87.5955  L 717.028125 87.5955  L 717.028125 32.1555  L 26.503125 32.1555  z " style="fill: #ffffff"/>
#    </g>
#    <g id="matplotlib.axis_1">
#     <g id="xtick_1">
#      <g id="line2d_1">
#       <defs>
#        <path id="m4f1dfd486a" d="M 0 0  L 0 3.5  " style="stroke: #000000; stroke-width: 0.8"/>
#       </defs>
#       <g>
#        <use xlink:href="#m4f1dfd486a" x="42.944196" y="87.5955" style="stroke: #000000; stroke-width: 0.8"/>
#       </g>
#      </g>
#      <g id="text_1">
#       <!-- −10.0 -->
#       <g transform="translate(27.62154 102.193937)scale(0.1 -0.1)">
#        <defs>
#         <path id="DejaVuSans-2212" d="M 678 2272  L 4684 2272  L 4684 1741  L 678 1741  L 678 2272  z " transform="scale(0.015625)"/>
#         <path id="DejaVuSans-31" d="M 794 531  L 1825 531  L 1825 4091  L 703 3866  L 703 4441  L 1819 4666  L 2450 4666  L 2450 531  L 3481 531  L 3481 0  L 794 0  L 794 531  z " transform="scale(0.015625)"/>
#         <path id="DejaVuSans-30" d="M 2034 4250  Q 1547 4250 1301 3770  Q 1056 3291 1056 2328  Q 1056 1369 1301 889  Q 1547 409 2034 409  Q 2525 409 2770 889  Q 3016 1369 3016 2328  Q 3016 3291 2770 3770  Q 2525 4250 2034 4250  z M 2034 4750  Q 2819 4750 3233 4129  Q 3647 3509 3647 2328  Q 3647 1150 3233 529  Q 2819 -91 2034 -91  Q 1250 -91 836 529  Q 422 1150 422 2328  Q 422 3509 836 4129  Q 1250 4750 2034 4750  z " transform="scale(0.015625)"/>
#         <path id="DejaVuSans-2e" d="M 684 794  L 1344 794  L 1344 0  L 684 0  L 684 794  z " transform="scale(0.015625)"/>
#        </defs>
#        <use xlink:href="#DejaVuSans-2212"/>
#        <use xlink:href="#DejaVuSans-31" x="83.789062"/>
#        <use xlink:href="#DejaVuSans-30" x="147.412109"/>
#        <use xlink:href="#DejaVuSans-2e" x="211.035156"/>
#        <use xlink:href="#DejaVuSans-30" x="242.822266"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_2">
#      <g id="line2d_2">
#       <g>
#        <use xlink:href="#m4f1dfd486a" x="371.765625" y="87.5955" style="stroke: #000000; stroke-width: 0.8"/>
#       </g>
#      </g>
#      <g id="text_2">
#       <!-- 2.5 -->
#       <g transform="translate(363.814063 102.193937)scale(0.1 -0.1)">
#        <defs>
#         <path id="DejaVuSans-32" d="M 1228 531  L 3431 531  L 3431 0  L 469 0  L 469 531  Q 828 903 1448 1529  Q 2069 2156 2228 2338  Q 2531 2678 2651 2914  Q 2772 3150 2772 3378  Q 2772 3750 2511 3984  Q 2250 4219 1831 4219  Q 1534 4219 1204 4116  Q 875 4013 500 3803  L 500 4441  Q 881 4594 1212 4672  Q 1544 4750 1819 4750  Q 2544 4750 2975 4387  Q 3406 4025 3406 3419  Q 3406 3131 3298 2873  Q 3191 2616 2906 2266  Q 2828 2175 2409 1742  Q 1991 1309 1228 531  z " transform="scale(0.015625)"/>
#         <path id="DejaVuSans-35" d="M 691 4666  L 3169 4666  L 3169 4134  L 1269 4134  L 1269 2991  Q 1406 3038 1543 3061  Q 1681 3084 1819 3084  Q 2600 3084 3056 2656  Q 3513 2228 3513 1497  Q 3513 744 3044 326  Q 2575 -91 1722 -91  Q 1428 -91 1123 -41  Q 819 9 494 109  L 494 744  Q 775 591 1075 516  Q 1375 441 1709 441  Q 2250 441 2565 725  Q 2881 1009 2881 1497  Q 2881 1984 2565 2268  Q 2250 2553 1709 2553  Q 1456 2553 1204 2497  Q 953 2441 691 2322  L 691 4666  z " transform="scale(0.015625)"/>
#        </defs>
#        <use xlink:href="#DejaVuSans-32"/>
#        <use xlink:href="#DejaVuSans-2e" x="63.623047"/>
#        <use xlink:href="#DejaVuSans-35" x="95.410156"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_3">
#      <g id="line2d_3">
#       <g>
#        <use xlink:href="#m4f1dfd486a" x="700.587054" y="87.5955" style="stroke: #000000; stroke-width: 0.8"/>
#       </g>
#      </g>
#      <g id="text_3">
#       <!-- 15.0 -->
#       <g transform="translate(689.454241 102.193937)scale(0.1 -0.1)">
#        <use xlink:href="#DejaVuSans-31"/>
#        <use xlink:href="#DejaVuSans-35" x="63.623047"/>
#        <use xlink:href="#DejaVuSans-2e" x="127.246094"/>
#        <use xlink:href="#DejaVuSans-30" x="159.033203"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_4">
#      <g id="line2d_4">
#       <path d="M 125.149554 87.5955  L 125.149554 32.1555  " clip-path="url(#p2e4b7976f6)" style="fill: none; stroke: #b0b0b0; stroke-width: 0.8; stroke-linecap: square"/>
#      </g>
#      <g id="line2d_5">
#       <defs>
#        <path id="m4a68c0be69" d="M 0 0  L 0 4  " style="stroke: #000000; stroke-width: 0.6"/>
#       </defs>
#       <g>
#        <use xlink:href="#m4a68c0be69" x="125.149554" y="87.5955" style="stroke: #000000; stroke-width: 0.6"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_5">
#      <g id="line2d_6">
#       <path d="M 207.354911 87.5955  L 207.354911 32.1555  " clip-path="url(#p2e4b7976f6)" style="fill: none; stroke: #b0b0b0; stroke-width: 0.8; stroke-linecap: square"/>
#      </g>
#      <g id="line2d_7">
#       <g>
#        <use xlink:href="#m4a68c0be69" x="207.354911" y="87.5955" style="stroke: #000000; stroke-width: 0.6"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_6">
#      <g id="line2d_8">
#       <path d="M 289.560268 87.5955  L 289.560268 32.1555  " clip-path="url(#p2e4b7976f6)" style="fill: none; stroke: #b0b0b0; stroke-width: 0.8; stroke-linecap: square"/>
#      </g>
#      <g id="line2d_9">
#       <g>
#        <use xlink:href="#m4a68c0be69" x="289.560268" y="87.5955" style="stroke: #000000; stroke-width: 0.6"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_7">
#      <g id="line2d_10">
#       <path d="M 453.970982 87.5955  L 453.970982 32.1555  " clip-path="url(#p2e4b7976f6)" style="fill: none; stroke: #b0b0b0; stroke-width: 0.8; stroke-linecap: square"/>
#      </g>
#      <g id="line2d_11">
#       <g>
#        <use xlink:href="#m4a68c0be69" x="453.970982" y="87.5955" style="stroke: #000000; stroke-width: 0.6"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_8">
#      <g id="line2d_12">
#       <path d="M 536.176339 87.5955  L 536.176339 32.1555  " clip-path="url(#p2e4b7976f6)" style="fill: none; stroke: #b0b0b0; stroke-width: 0.8; stroke-linecap: square"/>
#      </g>
#      <g id="line2d_13">
#       <g>
#        <use xlink:href="#m4a68c0be69" x="536.176339" y="87.5955" style="stroke: #000000; stroke-width: 0.6"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_9">
#      <g id="line2d_14">
#       <path d="M 618.381696 87.5955  L 618.38169
# BN{nodes: 8, arcs: 15, domainSize: 500000, dim: 495085, mem: 3Mo 835Ko 400o}
# ATE(exbn) = 1.9974318302904037

# %% [markdown]
# Varying the granularity of the discretization of covariates and the outcome variable yields different results in ATE estimation. For exact computations, the degree of discretization has minimal impact on the final result, as the expression of the outcome distribution is directly incorporated into the variable. However, in the case of learning estimators, a coarser discretization may hinder the model's ability to capture the intricacies of the outcome distribution, while an excessively fine discretization can introduce an excessive number of parameters to be learned from the data. Consequently, the quality of the estimation is sensitive to the discretization settings. Therefore, selecting the appropriate level of discretization is crucial for the accuracy of the estimators.
#
# For the proposed model, we observe that a 10-bin discretization for the covariates and an 80-bin discretization for the outcome yield superior results.

# %%
covariate_split_list = range(3,10,1)
outcome_split_list = [50]#]range(50,351,100)

e_grid = np.zeros((len(covariate_split_list), len(outcome_split_list)))

for i in range(len(covariate_split_list)):
    for j in range(len(outcome_split_list)):
        bn = getBN(covariate_num_split=covariate_split_list[i],
                   outcome_num_split=outcome_split_list[j])
        ate = ATE(bn)
        e_grid[i][j] = ate

        print(f"{covariate_split_list[i] = }, "\
              f"{outcome_split_list[j] = }, " \
              f"{ate = }")
# Out:
# covariate_split_list[i] = 3, outcome_split_list[j] = 50, ate = 1.9991830085861
# covariate_split_list[i] = 4, outcome_split_list[j] = 50, ate = 1.9989566899513704
# covariate_split_list[i] = 5, outcome_split_list[j] = 50, ate = 1.9974432482262623
# covariate_split_list[i] = 6, outcome_split_list[j] = 50, ate = 1.9978207054750636
# covariate_split_list[i] = 7, outcome_split_list[j] = 50, ate = 1.9978323873990393
# covariate_split_list[i] = 8, outcome_split_list[j] = 50, ate = 1.9978290354405743
# covariate_split_list[i] = 9, outcome_split_list[j] = 50, ate = 1.9978300616131652

# %%
plt.imshow(e_grid)
plt.yticks(np.arange(len(covariate_split_list)), labels=covariate_split_list)
plt.xticks(np.arange(len(outcome_split_list)), labels=outcome_split_list)
plt.colorbar()
plt.xlabel("Outcome number of splits")
plt.ylabel("Covariates number of splits")
plt.title("ATE Estimation")

plt.show()

# %% [markdown]
# ### 2 - Parameter Learning

# %% [markdown]
# We will first evaluate the results of the parameter learning algorithm using a Bayesian network where the variable domains come from the generated data. Here, we used `skbn.BNDiscretizer` with uniform discretization.

# %%
discretized_p_template = getBN(data=df, covariate_num_split=3, outcome_num_split=80)

# %%
disc_p_learner = gum.BNLearner(df, discretized_p_template)
disc_p_learner.useNMLCorrection()
disc_p_learner.useSmoothingPrior(1e-9)

disc_plbn = gum.BayesNet(discretized_p_template)
disc_p_learner.fitParameters(disc_plbn)

print(disc_p_learner)
# Out:
# Filename       : /tmp/tmpdw73qi56.csv
# Size           : (1000000,8)
# Variables      : X1[3], X2[3], X3[2], T[2], V1[3], V2[3], V3[2], Y[80]
# Induced types  : False
# Missing values : False
# Algorithm      : MIIC
# Score          : BDeu  (Not used for constraint-based algorithms)
# Correction     : NML  (Not used for score-based algorithms)
# Prior          : Smoothing
# Prior weight   : 0.000000

# %%
gnb.sideBySide(gnb.getInference(mutilateBN(disc_plbn), evs={"T":0}, targets={"Y"}),
               gnb.getInference(mutilateBN(disc_plbn), evs={"T":1}, targets={"Y"}),
               captions=["T=0", "T=1"])

print(disc_plbn)
print(f"{ATE(disc_plbn) = }")
# Out:
# <table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="470pt" height="258pt" viewBox="0.00 0.00 470.00 258.00">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 254)">
# <title>structs</title>
# <text text-anchor="middle" x="231" y="-7.8" font-family="Times,serif" font-size="14.00" fill="#4a4a4a">Inference in   1.40ms</text>
# <!-- X1 -->
# <g id="node1" class="node">
# <title>X1</title>
# <ellipse fill="#404040" stroke="#000000" cx="27" cy="-160" rx="27" ry="18"/>
# <text text-anchor="middle" x="27" y="-157.5" font-family="DejaVu Sans" font-size="10.00" fill="white">X1</text>
# </g>
# <!-- Y -->
# <g id="node8" class="node">
# <title>Y</title>
# <polygon fill="#e0e0e0" stroke="#000000" points="462,-106 24,-106 24,-23 462,-23 462,-106"/>
# <svg viewBox="0 0 582.322545 107.873625" width="438px" height="83px" preserveAspectRatio="xMinYMin meet" x="24" y="-106"> <metadata>
#   <rdf:RDF xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:cc="http://creativecommons.org/ns#" xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#">
#    <cc:Work>
#     <dc:type rdf:resource="http://purl.org/dc/dcmitype/StillImage"/>
#     <dc:date>2024-08-13T14:35:21.351642</dc:date>
#     <dc:format>image/svg+xml</dc:format>
#     <dc:creator>
#      <cc:Agent>
#       <dc:title>Matplotlib v3.5.1, https://matplotlib.org/</dc:title>
#      </cc:Agent>
#     </dc:creator>
#    </cc:Work>
#   </rdf:RDF>
#  </metadata>
#  <defs>
#   <style type="text/css">*{stroke-linejoin: round; stroke-linecap: butt}</style>
#  </defs>
#  <g id="figure_1">
#   <g id="patch_1">
#    <path d="M -0 107.873625  L 582.322545 107.873625  L 582.322545 0  L -0 0  z " style="fill: #e0e0e0"/>
#   </g>
#   <g id="axes_1">
#    <g id="patch_2">
#     <path d="M 26.503125 87.5955  L 577.528125 87.5955  L 577.528125 32.1555  L 26.503125 32.1555  z " style="fill: #ffffff"/>
#    </g>
#    <g id="matplotlib.axis_1">
#     <g id="xtick_1">
#      <g id="line2d_1">
#       <defs>
#        <path id="m9c389380b7" d="M 0 0  L 0 3.5  " style="stroke: #000000; stroke-width: 0.8"/>
#       </defs>
#       <g>
#        <use xlink:href="#m9c389380b7" x="39.622768" y="87.5955" style="stroke: #000000; stroke-width: 0.8"/>
#       </g>
#      </g>
#      <g id="text_1">
#       <!-- −15.90 -->
#       <g transform="translate(21.118862 102.193937)scale(0.1 -0.1)">
#        <defs>
#         <path id="DejaVuSans-2212" d="M 678 2272  L 4684 2272  L 4684 1741  L 678 1741  L 678 2272  z " transform="scale(0.015625)"/>
#         <path id="DejaVuSans-31" d="M 794 531  L 1825 531  L 1825 4091  L 703 3866  L 703 4441  L 1819 4666  L 2450 4666  L 2450 531  L 3481 531  L 3481 0  L 794 0  L 794 531  z " transform="scale(0.015625)"/>
#         <path id="DejaVuSans-35" d="M 691 4666  L 3169 4666  L 3169 4134  L 1269 4134  L 1269 2991  Q 1406 3038 1543 3061  Q 1681 3084 1819 3084  Q 2600 3084 3056 2656  Q 3513 2228 3513 1497  Q 3513 744 3044 326  Q 2575 -91 1722 -91  Q 1428 -91 1123 -41  Q 819 9 494 109  L 494 744  Q 775 591 1075 516  Q 1375 441 1709 441  Q 2250 441 2565 725  Q 2881 1009 2881 1497  Q 2881 1984 2565 2268  Q 2250 2553 1709 2553  Q 1456 2553 1204 2497  Q 953 2441 691 2322  L 691 4666  z " transform="scale(0.015625)"/>
#         <path id="DejaVuSans-2e" d="M 684 794  L 1344 794  L 1344 0  L 684 0  L 684 794  z " transform="scale(0.015625)"/>
#         <path id="DejaVuSans-39" d="M 703 97  L 703 672  Q 941 559 1184 500  Q 1428 441 1663 441  Q 2288 441 2617 861  Q 2947 1281 2994 2138  Q 2813 1869 2534 1725  Q 2256 1581 1919 1581  Q 1219 1581 811 2004  Q 403 2428 403 3163  Q 403 3881 828 4315  Q 1253 4750 1959 4750  Q 2769 4750 3195 4129  Q 3622 3509 3622 2328  Q 3622 1225 3098 567  Q 2575 -91 1691 -91  Q 1453 -91 1209 -44  Q 966 3 703 97  z M 1959 2075  Q 2384 2075 2632 2365  Q 2881 2656 2881 3163  Q 2881 3666 2632 3958  Q 2384 4250 1959 4250  Q 1534 4250 1286 3958  Q 1038 3666 1038 3163  Q 1038 2656 1286 2365  Q 1534 2075 1959 2075  z " transform="scale(0.015625)"/>
#         <path id="DejaVuSans-30" d="M 2034 4250  Q 1547 4250 1301 3770  Q 1056 3291 1056 2328  Q 1056 1369 1301 889  Q 1547 409 2034 409  Q 2525 409 2770 889  Q 3016 1369 3016 2328  Q 3016 3291 2770 3770  Q 2525 4250 2034 4250  z M 2034 4750  Q 2819 4750 3233 4129  Q 3647 3509 3647 2328  Q 3647 1150 3233 529  Q 2819 -91 2034 -91  Q 1250 -91 836 529  Q 422 1150 422 2328  Q 422 3509 836 4129  Q 1250 4750 2034 4750  z " transform="scale(0.015625)"/>
#        </defs>
#        <use xlink:href="#DejaVuSans-2212"/>
#        <use xlink:href="#DejaVuSans-31" x="83.789062"/>
#        <use xlink:href="#DejaVuSans-35" x="147.412109"/>
#        <use xlink:href="#DejaVuSans-2e" x="211.035156"/>
#        <use xlink:href="#DejaVuSans-39" x="242.822266"/>
#        <use xlink:href="#DejaVuSans-30" x="306.445312"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_2">
#      <g id="line2d_2">
#       <g>
#        <use xlink:href="#m9c389380b7" x="302.015625" y="87.5955" style="stroke: #000000; stroke-width: 0.8"/>
#       </g>
#      </g>
#      <g id="text_2">
#       <!-- 2.86 -->
#       <g transform="translate(290.882812 102.193937)scale(0.1 -0.1)">
#        <defs>
#         <path id="DejaVuSans-32" d="M 1228 531  L 3431 531  L 3431 0  L 469 0  L 469 531  Q 828 903 1448 1529  Q 2069 2156 2228 2338  Q 2531 2678 2651 2914  Q 2772 3150 2772 3378  Q 2772 3750 2511 3984  Q 2250 4219 1831 4219  Q 1534 4219 1204 4116  Q 875 4013 500 3803  L 500 4441  Q 881 4594 1212 4672  Q 1544 4750 1819 4750  Q 2544 4750 2975 4387  Q 3406 4025 3406 3419  Q 3406 3131 3298 2873  Q 3191 2616 2906 2266  Q 2828 2175 2409 1742  Q 1991 1309 1228 531  z " transform="scale(0.015625)"/>
#         <path id="DejaVuSans-38" d="M 2034 2216  Q 1584 2216 1326 1975  Q 1069 1734 1069 1313  Q 1069 891 1326 650  Q 1584 409 2034 409  Q 2484 409 2743 651  Q 3003 894 3003 1313  Q 3003 1734 2745 1975  Q 2488 2216 2034 2216  z M 1403 2484  Q 997 2584 770 2862  Q 544 3141 544 3541  Q 544 4100 942 4425  Q 1341 4750 2034 4750  Q 2731 4750 3128 4425  Q 3525 4100 3525 3541  Q 3525 3141 3298 2862  Q 3072 2584 2669 2484  Q 3125 2378 3379 2068  Q 3634 1759 3634 1313  Q 3634 634 3220 271  Q 2806 -91 2034 -91  Q 1263 -91 848 271  Q 434 634 434 1313  Q 434 1759 690 2068  Q 947 2378 1403 2484  z M 1172 3481  Q 1172 3119 1398 2916  Q 1625 2713 2034 2713  Q 2441 2713 2670 2916  Q 2900 3119 2900 3481  Q 2900 3844 2670 4047  Q 2441 4250 2034 4250  Q 1625 4250 1398 4047  Q 1172 3844 1172 3481  z " transform="scale(0.015625)"/>
#         <path id="DejaVuSans-36" d="M 2113 2584  Q 1688 2584 1439 2293  Q 1191 2003 1191 1497  Q 1191 994 1439 701  Q 1688 409 2113 409  Q 2538 409 2786 701  Q 3034 994 3034 1497  Q 3034 2003 2786 2293  Q 2538 2584 2113 2584  z M 3366 4563  L 3366 3988  Q 3128 4100 2886 4159  Q 2644 4219 2406 4219  Q 1781 4219 1451 3797  Q 1122 3375 1075 2522  Q 1259 2794 1537 2939  Q 1816 3084 2150 3084  Q 2853 3084 3261 2657  Q 3669 2231 3669 1497  Q 3669 778 3244 343  Q 2819 -91 2113 -91  Q 1303 -91 875 529  Q 447 1150 447 2328  Q 447 3434 972 4092  Q 1497 4750 2381 4750  Q 2619 4750 2861 4703  Q 3103 4656 3366 4563  z " transform="scale(0.015625)"/>
#        </defs>
#        <use xlink:href="#DejaVuSans-32"/>
#        <use xlink:href="#DejaVuSans-2e" x="63.623047"/>
#        <use xlink:href="#DejaVuSans-38" x="95.410156"/>
#        <use xlink:href="#DejaVuSans-36" x="159.033203"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_3">
#      <g id="line2d_3">
#       <g>
#        <use xlink:href="#m9c389380b7" x="564.408482" y="87.5955" style="stroke: #000000; stroke-width: 0.8"/>
#       </g>
#      </g>
#      <g id="text_3">
#       <!-- 21.61 -->
#       <g transform="translate(550.09442 102.193937)scale(0.1 -0.1)">
#        <use xlink:href="#DejaVuSans-32"/>
#        <use xlink:href="#DejaVuSans-31" x="63.623047"/>
#        <use xlink:href="#DejaVuSans-2e" x="127.246094"/>
#        <use xlink:href="#DejaVuSans-36" x="159.033203"/>
#        <use xlink:h
# BN{nodes: 8, arcs: 15, domainSize: 51840, dim: 51229, mem: 405Ko 528o}
# ATE(disc_plbn) = 1.2043430028053494

# %% [markdown]
# The estimated ATE is slightly less than the expected ATE of 2.
#
# Next, we will evaluate the performance of the parameter learning algorithm when provided the same custom template as the exact Baysian Network.

# %%
custom_p_template = getBN(fill_distribution=False, covariate_num_split=9, outcome_num_split=80)

# %%
cstm_p_learner = gum.BNLearner(df, custom_p_template)
cstm_p_learner.useNMLCorrection()
cstm_p_learner.useSmoothingPrior(1e-9)

cstm_plbn = gum.BayesNet(custom_p_template)
cstm_p_learner.fitParameters(cstm_plbn)

print(cstm_p_learner)
# Out:
# Filename       : /tmp/tmpoqn0jrf7.csv
# Size           : (1000000,8)
# Variables      : X1[9], V1[9], X2[9], V2[9], X3[2], V3[2], T[2], Y[80]
# Induced types  : False
# Missing values : False
# Algorithm      : MIIC
# Score          : BDeu  (Not used for constraint-based algorithms)
# Correction     : NML  (Not used for score-based algorithms)
# Prior          : Smoothing
# Prior weight   : 0.000000

# %%
gnb.sideBySide(gnb.getInference(mutilateBN(cstm_plbn), evs={"T":0}, targets={"Y"}),
               gnb.getInference(mutilateBN(cstm_plbn), evs={"T":1}, targets={"Y"}),
               captions=["T=0", "T=1"])

print(cstm_plbn)
print(f"{ATE(cstm_plbn) = }")
# Out:
# <table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="470pt" height="258pt" viewBox="0.00 0.00 469.50 258.00">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 254)">
# <title>structs</title>
# <text text-anchor="middle" x="230.75" y="-7.8" font-family="Times,serif" font-size="14.00" fill="#4a4a4a">Inference in  43.66ms</text>
# <!-- X1 -->
# <g id="node1" class="node">
# <title>X1</title>
# <ellipse fill="#404040" stroke="#000000" cx="27" cy="-160" rx="27" ry="18"/>
# <text text-anchor="middle" x="27" y="-157.5" font-family="DejaVu Sans" font-size="10.00" fill="white">X1</text>
# </g>
# <!-- Y -->
# <g id="node8" class="node">
# <title>Y</title>
# <polygon fill="#e0e0e0" stroke="#000000" points="461.5,-106 24.5,-106 24.5,-23 461.5,-23 461.5,-106"/>
# <svg viewBox="0 0 581.128125 107.873625" width="437px" height="83px" preserveAspectRatio="xMinYMin meet" x="24.5" y="-106"> <metadata>
#   <rdf:RDF xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:cc="http://creativecommons.org/ns#" xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#">
#    <cc:Work>
#     <dc:type rdf:resource="http://purl.org/dc/dcmitype/StillImage"/>
#     <dc:date>2024-08-13T14:35:30.303883</dc:date>
#     <dc:format>image/svg+xml</dc:format>
#     <dc:creator>
#      <cc:Agent>
#       <dc:title>Matplotlib v3.5.1, https://matplotlib.org/</dc:title>
#      </cc:Agent>
#     </dc:creator>
#    </cc:Work>
#   </rdf:RDF>
#  </metadata>
#  <defs>
#   <style type="text/css">*{stroke-linejoin: round; stroke-linecap: butt}</style>
#  </defs>
#  <g id="figure_1">
#   <g id="patch_1">
#    <path d="M -0 107.873625  L 581.128125 107.873625  L 581.128125 0  L -0 0  z " style="fill: #e0e0e0"/>
#   </g>
#   <g id="axes_1">
#    <g id="patch_2">
#     <path d="M 26.503125 87.5955  L 577.528125 87.5955  L 577.528125 32.1555  L 26.503125 32.1555  z " style="fill: #ffffff"/>
#    </g>
#    <g id="matplotlib.axis_1">
#     <g id="xtick_1">
#      <g id="line2d_1">
#       <defs>
#        <path id="mb914f801a2" d="M 0 0  L 0 3.5  " style="stroke: #000000; stroke-width: 0.8"/>
#       </defs>
#       <g>
#        <use xlink:href="#mb914f801a2" x="39.622768" y="87.5955" style="stroke: #000000; stroke-width: 0.8"/>
#       </g>
#      </g>
#      <g id="text_1">
#       <!-- −10.0 -->
#       <g transform="translate(24.300112 102.193937)scale(0.1 -0.1)">
#        <defs>
#         <path id="DejaVuSans-2212" d="M 678 2272  L 4684 2272  L 4684 1741  L 678 1741  L 678 2272  z " transform="scale(0.015625)"/>
#         <path id="DejaVuSans-31" d="M 794 531  L 1825 531  L 1825 4091  L 703 3866  L 703 4441  L 1819 4666  L 2450 4666  L 2450 531  L 3481 531  L 3481 0  L 794 0  L 794 531  z " transform="scale(0.015625)"/>
#         <path id="DejaVuSans-30" d="M 2034 4250  Q 1547 4250 1301 3770  Q 1056 3291 1056 2328  Q 1056 1369 1301 889  Q 1547 409 2034 409  Q 2525 409 2770 889  Q 3016 1369 3016 2328  Q 3016 3291 2770 3770  Q 2525 4250 2034 4250  z M 2034 4750  Q 2819 4750 3233 4129  Q 3647 3509 3647 2328  Q 3647 1150 3233 529  Q 2819 -91 2034 -91  Q 1250 -91 836 529  Q 422 1150 422 2328  Q 422 3509 836 4129  Q 1250 4750 2034 4750  z " transform="scale(0.015625)"/>
#         <path id="DejaVuSans-2e" d="M 684 794  L 1344 794  L 1344 0  L 684 0  L 684 794  z " transform="scale(0.015625)"/>
#        </defs>
#        <use xlink:href="#DejaVuSans-2212"/>
#        <use xlink:href="#DejaVuSans-31" x="83.789062"/>
#        <use xlink:href="#DejaVuSans-30" x="147.412109"/>
#        <use xlink:href="#DejaVuSans-2e" x="211.035156"/>
#        <use xlink:href="#DejaVuSans-30" x="242.822266"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_2">
#      <g id="line2d_2">
#       <g>
#        <use xlink:href="#mb914f801a2" x="302.015625" y="87.5955" style="stroke: #000000; stroke-width: 0.8"/>
#       </g>
#      </g>
#      <g id="text_2">
#       <!-- 2.5 -->
#       <g transform="translate(294.064063 102.193937)scale(0.1 -0.1)">
#        <defs>
#         <path id="DejaVuSans-32" d="M 1228 531  L 3431 531  L 3431 0  L 469 0  L 469 531  Q 828 903 1448 1529  Q 2069 2156 2228 2338  Q 2531 2678 2651 2914  Q 2772 3150 2772 3378  Q 2772 3750 2511 3984  Q 2250 4219 1831 4219  Q 1534 4219 1204 4116  Q 875 4013 500 3803  L 500 4441  Q 881 4594 1212 4672  Q 1544 4750 1819 4750  Q 2544 4750 2975 4387  Q 3406 4025 3406 3419  Q 3406 3131 3298 2873  Q 3191 2616 2906 2266  Q 2828 2175 2409 1742  Q 1991 1309 1228 531  z " transform="scale(0.015625)"/>
#         <path id="DejaVuSans-35" d="M 691 4666  L 3169 4666  L 3169 4134  L 1269 4134  L 1269 2991  Q 1406 3038 1543 3061  Q 1681 3084 1819 3084  Q 2600 3084 3056 2656  Q 3513 2228 3513 1497  Q 3513 744 3044 326  Q 2575 -91 1722 -91  Q 1428 -91 1123 -41  Q 819 9 494 109  L 494 744  Q 775 591 1075 516  Q 1375 441 1709 441  Q 2250 441 2565 725  Q 2881 1009 2881 1497  Q 2881 1984 2565 2268  Q 2250 2553 1709 2553  Q 1456 2553 1204 2497  Q 953 2441 691 2322  L 691 4666  z " transform="scale(0.015625)"/>
#        </defs>
#        <use xlink:href="#DejaVuSans-32"/>
#        <use xlink:href="#DejaVuSans-2e" x="63.623047"/>
#        <use xlink:href="#DejaVuSans-35" x="95.410156"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_3">
#      <g id="line2d_3">
#       <g>
#        <use xlink:href="#mb914f801a2" x="564.408482" y="87.5955" style="stroke: #000000; stroke-width: 0.8"/>
#       </g>
#      </g>
#      <g id="text_3">
#       <!-- 15.0 -->
#       <g transform="translate(553.27567 102.193937)scale(0.1 -0.1)">
#        <use xlink:href="#DejaVuSans-31"/>
#        <use xlink:href="#DejaVuSans-35" x="63.623047"/>
#        <use xlink:href="#DejaVuSans-2e" x="127.246094"/>
#        <use xlink:href="#DejaVuSans-30" x="159.033203"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_4">
#      <g id="line2d_4">
#       <path d="M 105.220982 87.5955  L 105.220982 32.1555  " clip-path="url(#p88007b8183)" style="fill: none; stroke: #b0b0b0; stroke-width: 0.8; stroke-linecap: square"/>
#      </g>
#      <g id="line2d_5">
#       <defs>
#        <path id="m713a517ba3" d="M 0 0  L 0 4  " style="stroke: #000000; stroke-width: 0.6"/>
#       </defs>
#       <g>
#        <use xlink:href="#m713a517ba3" x="105.220982" y="87.5955" style="stroke: #000000; stroke-width: 0.6"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_5">
#      <g id="line2d_6">
#       <path d="M 170.819196 87.5955  L 170.819196 32.1555  " clip-path="url(#p88007b8183)" style="fill: none; stroke: #b0b0b0; stroke-width: 0.8; stroke-linecap: square"/>
#      </g>
#      <g id="line2d_7">
#       <g>
#        <use xlink:href="#m713a517ba3" x="170.819196" y="87.5955" style="stroke: #000000; stroke-width: 0.6"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_6">
#      <g id="line2d_8">
#       <path d="M 236.417411 87.5955  L 236.417411 32.1555  " clip-path="url(#p88007b8183)" style="fill: none; stroke: #b0b0b0; stroke-width: 0.8; stroke-linecap: square"/>
#      </g>
#      <g id="line2d_9">
#       <g>
#        <use xlink:href="#m713a517ba3" x="236.417411" y="87.5955" style="stroke: #000000; stroke-width: 0.6"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_7">
#      <g id="line2d_10">
#       <path d="M 367.613839 87.5955  L 367.613839 32.1555  " clip-path="url(#p88007b8183)" style="fill: none; stroke: #b0b0b0; stroke-width: 0.8; stroke-linecap: square"/>
#      </g>
#      <g id="line2d_11">
#       <g>
#        <use xlink:href="#m713a517ba3" x="367.613839" y="87.5955" style="stroke: #000000; stroke-width: 0.6"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_8">
#      <g id="line2d_12">
#       <path d="M 433.212054 87.5955  L 433.212054 32.1555  " clip-path="url(#p88007b8183)" style="fill: none; stroke: #b0b0b0; stroke-width: 0.8; stroke-linecap: square"/>
#      </g>
#      <g id="line2d_13">
#       <g>
#        <use xlink:href="#m713a517ba3" x="433.212054" y="87.5955" style="stroke: #000000; stroke-width: 0.6"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_9">
#      <g id="line2d_14">
#       <path d="M 498.810268
# BN{nodes: 8, arcs: 15, domainSize: 10^6.62315, dim: 4146781, mem: 32Mo 40Ko 144o}
# ATE(cstm_plbn) = 1.7516956535880326

# %% [markdown]
# The estimated ATE is similar to the previously obtained one when using the discretized template. However, given that this approach is computationally much faster, we will use it to plot the estimated ATE's evolution as the number of observations increases.

# %%
p_template = custom_p_template

num_obs_list = [5e4, 1e5, 2e5, 4e5]
num_shots = 10
pl_tau_hat_arr = list()

for i in num_obs_list:
    pl_tau_hat_arr.append(list())
    for j in range(num_shots):
        df = generate_lunceford(int(i))

        p_learner = gum.BNLearner(df, p_template)
        p_learner.useNMLCorrection()
        p_learner.useSmoothingPrior(1e-9)

        plbn = gum.BayesNet(p_template)
        p_learner.fitParameters(plbn)

        pl_tau_hat_arr[-1].append(ATE(plbn))

# %%
plt.boxplot(pl_tau_hat_arr, labels=num_obs_list, meanline=False,
            showmeans=True, showcaps=True)
#plt.axhline(y=2, color='r', linestyle='--', linewidth=1)
plt.title(f"Parameter Learning ATE evolution ({num_shots} runs)")
plt.xlabel("Number of observations")
plt.ylabel(r"$\hat{ATE}$")
plt.grid(True)
plt.show()

# %%
covariate_split_list = range(3,10,1)
outcome_split_list = [50]#range(50,351,100)

ratio = 0.2

p_grid = np.zeros((len(covariate_split_list), len(outcome_split_list)))

for i in range(len(covariate_split_list)):
    for j in range(len(outcome_split_list)):
        template = getBN(data=df, fill_distribution=False,
                         covariate_num_split=covariate_split_list[i],
                         outcome_num_split=outcome_split_list[j])
        exbn = getBN(data=df,
                     covariate_num_split=covariate_split_list[i],
                     outcome_num_split=outcome_split_list[j])

        p_learner = gum.BNLearner(df, template)
        p_learner.useNMLCorrection()

        #p_learner.useSmoothingPrior(1e-9)
        p_learner.useDirichletPrior(exbn)

        bn = gum.BayesNet(template)
        p_learner.fitParameters(bn)

        ate = ATE(bn)
        p_grid[i][j] = ate

        print(f"{covariate_split_list[i] = }, "\
              f"{outcome_split_list[j] = }, " \
              f"{ate = }")

p_grid[p_grid == 0.0] = None
# Out:
# covariate_split_list[i] = 3, outcome_split_list[j] = 50, ate = 1.2918401890554192
# covariate_split_list[i] = 4, outcome_split_list[j] = 50, ate = 1.4588767231752726
# covariate_split_list[i] = 5, outcome_split_list[j] = 50, ate = 1.6987106056623782
# covariate_split_list[i] = 6, outcome_split_list[j] = 50, ate = 1.7555896282337795
# covariate_split_list[i] = 7, outcome_split_list[j] = 50, ate = 1.8226358899825488
# covariate_split_list[i] = 8, outcome_split_list[j] = 50, ate = 1.8595935481464314
# covariate_split_list[i] = 9, outcome_split_list[j] = 50, ate = 1.890309486308385

# %%
plt.imshow(p_grid)
plt.yticks(np.arange(len(covariate_split_list)), labels=covariate_split_list)
plt.xticks(np.arange(len(outcome_split_list)), labels=outcome_split_list)
plt.colorbar()
plt.xlabel("Outcome number of splits")
plt.ylabel("Covariates number of splits")
plt.title("ATE Estimation")

plt.show()

# %% [markdown]
# ### 3 - Structure Learning

# %% [markdown]
# As before, structure learning can be performed on discretized variables derived from the data or by specifying the variables to be used in the process. Here, we observed that a 5-bins discretisation for the covariates and the outcome yielded the best results.

# %%
discretized_s_template = getBN(data=df, add_arcs=False, covariate_num_split=5, outcome_num_split=5)

# %%
disc_s_learner = gum.BNLearner(df, discretized_s_template)
disc_s_learner.useNMLCorrection()
disc_s_learner.useSmoothingPrior(1e-6)
disc_s_learner.setSliceOrder([["X3"], ["X1","X2","V1","V2","V3"], ["T"], ["Y"]])
disc_slbn = disc_s_learner.learnBN()

print(disc_s_learner)
# Out:
# Filename               : /tmp/tmpnopl88mr.csv
# Size                   : (400000,8)
# Variables              : X1[5], X2[5], X3[2], T[2], V1[5], V2[5], V3[2], Y[5]
# Induced types          : False
# Missing values         : False
# Algorithm              : MIIC
# Score                  : BDeu  (Not used for constraint-based algorithms)
# Correction             : NML  (Not used for score-based algorithms)
# Prior                  : Smoothing
# Prior weight           : 0.000001
# Constraint Slice Order : {T:2, X2:1, V3:1, V1:1, Y:3, X3:0, X1:1, V2:1}

# %%
gnb.showBN(disc_slbn, size="50")

# %%
gnb.sideBySide(gnb.getInference(mutilateBN(disc_slbn), evs={"T":0}, targets={"Y"}),
               gnb.getInference(mutilateBN(disc_slbn), evs={"T":1}, targets={"Y"}),
               captions=["T=0", "T=1"])

print(disc_slbn)
print(f"{ATE(disc_slbn) = }")
# Out:
# <table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="324pt" height="474pt" viewBox="0.00 0.00 324.00 474.00">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 470)">
# <title>structs</title>
# <text text-anchor="middle" x="158" y="-7.8" font-family="Times,serif" font-size="14.00" fill="#4a4a4a">Inference in   0.46ms</text>
# <!-- X1 -->
# <g id="node1" class="node">
# <title>X1</title>
# <ellipse fill="#404040" stroke="#000000" cx="27" cy="-304" rx="27" ry="18"/>
# <text text-anchor="middle" x="27" y="-301.5" font-family="DejaVu Sans" font-size="10.00" fill="white">X1</text>
# </g>
# <!-- V2 -->
# <g id="node6" class="node">
# <title>V2</title>
# <ellipse fill="#404040" stroke="#000000" cx="48" cy="-232" rx="27" ry="18"/>
# <text text-anchor="middle" x="48" y="-229.5" font-family="DejaVu Sans" font-size="10.00" fill="white">V2</text>
# </g>
# <!-- X1&#45;&gt;V2 -->
# <g id="edge13" class="edge">
# <title>X1-&gt;V2</title>
# <g id="a_edge13"><a xlink:title="0 → 5">
# <path fill="none" stroke="#4a4a4a" d="M32.08,-286.05C34.48,-278.06 37.4,-268.33 40.08,-259.4"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="43.44,-260.37 42.96,-249.79 36.74,-258.36 43.44,-260.37"/>
# </a>
# </g>
# </g>
# <!-- Y -->
# <g id="node8" class="node">
# <title>Y</title>
# <polygon fill="#e0e0e0" stroke="#000000" points="188.5,-106 93.5,-106 93.5,-23 188.5,-23 188.5,-106"/>
# <svg viewBox="0 0 124.200625 107.873625" width="95px" height="83px" preserveAspectRatio="xMinYMin meet" x="93.5" y="-106"> <metadata>
#   <rdf:RDF xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:cc="http://creativecommons.org/ns#" xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#">
#    <cc:Work>
#     <dc:type rdf:resource="http://purl.org/dc/dcmitype/StillImage"/>
#     <dc:date>2024-08-13T15:26:39.438991</dc:date>
#     <dc:format>image/svg+xml</dc:format>
#     <dc:creator>
#      <cc:Agent>
#       <dc:title>Matplotlib v3.5.1, https://matplotlib.org/</dc:title>
#      </cc:Agent>
#     </dc:creator>
#    </cc:Work>
#   </rdf:RDF>
#  </metadata>
#  <defs>
#   <style type="text/css">*{stroke-linejoin: round; stroke-linecap: butt}</style>
#  </defs>
#  <g id="figure_1">
#   <g id="patch_1">
#    <path d="M 0 107.873625  L 124.200625 107.873625  L 124.200625 0  L 0 0  z " style="fill: #e0e0e0"/>
#   </g>
#   <g id="axes_1">
#    <g id="patch_2">
#     <path d="M 32.865625 87.5955  L 102.615625 87.5955  L 102.615625 32.1555  L 32.865625 32.1555  z " style="fill: #ffffff"/>
#    </g>
#    <g id="matplotlib.axis_1">
#     <g id="xtick_1">
#      <g id="line2d_1">
#       <defs>
#        <path id="m5ca2fc3d4b" d="M 0 0  L 0 3.5  " style="stroke: #000000; stroke-width: 0.8"/>
#       </defs>
#       <g>
#        <use xlink:href="#m5ca2fc3d4b" x="34.526339" y="87.5955" style="stroke: #000000; stroke-width: 0.8"/>
#       </g>
#      </g>
#      <g id="text_1">
#       <!-- −15.50 -->
#       <g transform="translate(16.022433 102.193937)scale(0.1 -0.1)">
#        <defs>
#         <path id="DejaVuSans-2212" d="M 678 2272  L 4684 2272  L 4684 1741  L 678 1741  L 678 2272  z " transform="scale(0.015625)"/>
#         <path id="DejaVuSans-31" d="M 794 531  L 1825 531  L 1825 4091  L 703 3866  L 703 4441  L 1819 4666  L 2450 4666  L 2450 531  L 3481 531  L 3481 0  L 794 0  L 794 531  z " transform="scale(0.015625)"/>
#         <path id="DejaVuSans-35" d="M 691 4666  L 3169 4666  L 3169 4134  L 1269 4134  L 1269 2991  Q 1406 3038 1543 3061  Q 1681 3084 1819 3084  Q 2600 3084 3056 2656  Q 3513 2228 3513 1497  Q 3513 744 3044 326  Q 2575 -91 1722 -91  Q 1428 -91 1123 -41  Q 819 9 494 109  L 494 744  Q 775 591 1075 516  Q 1375 441 1709 441  Q 2250 441 2565 725  Q 2881 1009 2881 1497  Q 2881 1984 2565 2268  Q 2250 2553 1709 2553  Q 1456 2553 1204 2497  Q 953 2441 691 2322  L 691 4666  z " transform="scale(0.015625)"/>
#         <path id="DejaVuSans-2e" d="M 684 794  L 1344 794  L 1344 0  L 684 0  L 684 794  z " transform="scale(0.015625)"/>
#         <path id="DejaVuSans-30" d="M 2034 4250  Q 1547 4250 1301 3770  Q 1056 3291 1056 2328  Q 1056 1369 1301 889  Q 1547 409 2034 409  Q 2525 409 2770 889  Q 3016 1369 3016 2328  Q 3016 3291 2770 3770  Q 2525 4250 2034 4250  z M 2034 4750  Q 2819 4750 3233 4129  Q 3647 3509 3647 2328  Q 3647 1150 3233 529  Q 2819 -91 2034 -91  Q 1250 -91 836 529  Q 422 1150 422 2328  Q 422 3509 836 4129  Q 1250 4750 2034 4750  z " transform="scale(0.015625)"/>
#        </defs>
#        <use xlink:href="#DejaVuSans-2212"/>
#        <use xlink:href="#DejaVuSans-31" x="83.789062"/>
#        <use xlink:href="#DejaVuSans-35" x="147.412109"/>
#        <use xlink:href="#DejaVuSans-2e" x="211.035156"/>
#        <use xlink:href="#DejaVuSans-35" x="242.822266"/>
#        <use xlink:href="#DejaVuSans-30" x="306.445312"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_2">
#      <g id="line2d_2">
#       <g>
#        <use xlink:href="#m5ca2fc3d4b" x="67.740625" y="87.5955" style="stroke: #000000; stroke-width: 0.8"/>
#       </g>
#      </g>
#      <g id="text_2">
#       <!-- 2.29 -->
#       <g transform="translate(56.607813 102.193937)scale(0.1 -0.1)">
#        <defs>
#         <path id="DejaVuSans-32" d="M 1228 531  L 3431 531  L 3431 0  L 469 0  L 469 531  Q 828 903 1448 1529  Q 2069 2156 2228 2338  Q 2531 2678 2651 2914  Q 2772 3150 2772 3378  Q 2772 3750 2511 3984  Q 2250 4219 1831 4219  Q 1534 4219 1204 4116  Q 875 4013 500 3803  L 500 4441  Q 881 4594 1212 4672  Q 1544 4750 1819 4750  Q 2544 4750 2975 4387  Q 3406 4025 3406 3419  Q 3406 3131 3298 2873  Q 3191 2616 2906 2266  Q 2828 2175 2409 1742  Q 1991 1309 1228 531  z " transform="scale(0.015625)"/>
#         <path id="DejaVuSans-39" d="M 703 97  L 703 672  Q 941 559 1184 500  Q 1428 441 1663 441  Q 2288 441 2617 861  Q 2947 1281 2994 2138  Q 2813 1869 2534 1725  Q 2256 1581 1919 1581  Q 1219 1581 811 2004  Q 403 2428 403 3163  Q 403 3881 828 4315  Q 1253 4750 1959 4750  Q 2769 4750 3195 4129  Q 3622 3509 3622 2328  Q 3622 1225 3098 567  Q 2575 -91 1691 -91  Q 1453 -91 1209 -44  Q 966 3 703 97  z M 1959 2075  Q 2384 2075 2632 2365  Q 2881 2656 2881 3163  Q 2881 3666 2632 3958  Q 2384 4250 1959 4250  Q 1534 4250 1286 3958  Q 1038 3666 1038 3163  Q 1038 2656 1286 2365  Q 1534 2075 1959 2075  z " transform="scale(0.015625)"/>
#        </defs>
#        <use xlink:href="#DejaVuSans-32"/>
#        <use xlink:href="#DejaVuSans-2e" x="63.623047"/>
#        <use xlink:href="#DejaVuSans-32" x="95.410156"/>
#        <use xlink:href="#DejaVuSans-39" x="159.033203"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_3">
#      <g id="line2d_3">
#       <g>
#        <use xlink:href="#m5ca2fc3d4b" x="100.954911" y="87.5955" style="stroke: #000000; stroke-width: 0.8"/>
#       </g>
#      </g>
#      <g id="text_3">
#       <!-- 20.09 -->
#       <g transform="translate(86.640848 102.193937)scale(0.1 -0.1)">
#        <use xlink:href="#DejaVuSans-32"/>
#        <use xlink:href="#DejaVuSans-30" x="63.623047"/>
#        <use xlink:href="#DejaVuSans-2e" x="127.246094"/>
#        <use xlink:href="#DejaVuSans-30" x="159.033203"/>
#        <use xlink:href="#DejaVuSans-39" x="222.65625"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_4">
#      <g id="line2d_4">
#       <path d="M 42.829911 87.5955  L 42.829911 32.1555  " clip-path="url(#p785220c434)" style="fill: none; stroke: #b0b0b0; stroke-width: 0.8; stroke-linecap: square"/>
#      </g>
#      <g id="line2d_5">
#       <defs>
#        <path id="m0f0f53e5ce" d="M 0 0  L 0 4  " style="stroke: #000000; stroke-width: 0.6"/>
#       </defs>
#       <g>
#        <use xlink:href="#m0f0f53e5ce" x="42.829911" y="87.5955" style="stroke: #000000; stroke-width: 0.6"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_5">
#      <g id="line2d_6">
#       <path d="M 51.133482 87.5955  L 51.133482 32.1555  " clip-path="url(#p785220c434)" style="fill: none; stroke: #b0b0b0; stroke-width: 0.8; stroke-linecap: square"/>
#      </g>
#      <g id="line2d_7">
#       <g>
#        <use xlink:href="#m0f0f5
# BN{nodes: 8, arcs: 20, domainSize: 25000, dim: 20541, mem: 202Ko 80o}
# ATE(disc_slbn) = 1.7769010786979305

# %% [markdown]
# The structure learning algorithm using discretized variables performs slightly worse than the parameter learning algorithm, as evidenced by the greater bias of the ATE.

# %%
custom_s_template = getBN(fill_distribution=False, add_arcs=False, covariate_num_split=5, outcome_num_split=5)

# %%
cstm_s_learner = gum.BNLearner(df, custom_s_template)
cstm_s_learner.useNMLCorrection()
cstm_s_learner.useSmoothingPrior(1e-6)
cstm_s_learner.setSliceOrder([["X3"], ["X1","X2","V1","V2","V3"], ["T"], ["Y"]])
cstm_slbn = cstm_s_learner.learnBN()

print(cstm_s_learner)
# Out:
# Filename               : /tmp/tmp7ygyx19j.csv
# Size                   : (400000,8)
# Variables              : X1[5], V1[5], X2[5], V2[5], X3[2], V3[2], T[2], Y[5]
# Induced types          : False
# Missing values         : False
# Algorithm              : MIIC
# Score                  : BDeu  (Not used for constraint-based algorithms)
# Correction             : NML  (Not used for score-based algorithms)
# Prior                  : Smoothing
# Prior weight           : 0.000001
# Constraint Slice Order : {V2:1, V1:1, T:2, X3:0, Y:3, X1:1, X2:1, V3:1}

# %%
gnb.showBN(cstm_slbn, size="50")

# %%
gnb.sideBySide(gnb.getInference(mutilateBN(cstm_slbn), evs={"T":0}, targets={"Y"}),
               gnb.getInference(mutilateBN(cstm_slbn), evs={"T":1}, targets={"Y"}),
               captions=["T=0", "T=1"])

print(cstm_slbn)
print(f"{ATE(cstm_slbn) = }")
# Out:
# <table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="460pt" height="258pt" viewBox="0.00 0.00 460.00 258.00">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 254)">
# <title>structs</title>
# <text text-anchor="middle" x="226" y="-7.8" font-family="Times,serif" font-size="14.00" fill="#4a4a4a">Inference in   0.64ms</text>
# <!-- X1 -->
# <g id="node1" class="node">
# <title>X1</title>
# <ellipse fill="#404040" stroke="#000000" cx="27" cy="-160" rx="27" ry="18"/>
# <text text-anchor="middle" x="27" y="-157.5" font-family="DejaVu Sans" font-size="10.00" fill="white">X1</text>
# </g>
# <!-- Y -->
# <g id="node8" class="node">
# <title>Y</title>
# <polygon fill="#e0e0e0" stroke="#000000" points="290.5,-106 195.5,-106 195.5,-23 290.5,-23 290.5,-106"/>
# <svg viewBox="0 0 124.020625 107.873625" width="95px" height="83px" preserveAspectRatio="xMinYMin meet" x="195.5" y="-106"> <metadata>
#   <rdf:RDF xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:cc="http://creativecommons.org/ns#" xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#">
#    <cc:Work>
#     <dc:type rdf:resource="http://purl.org/dc/dcmitype/StillImage"/>
#     <dc:date>2024-08-13T15:27:50.633782</dc:date>
#     <dc:format>image/svg+xml</dc:format>
#     <dc:creator>
#      <cc:Agent>
#       <dc:title>Matplotlib v3.5.1, https://matplotlib.org/</dc:title>
#      </cc:Agent>
#     </dc:creator>
#    </cc:Work>
#   </rdf:RDF>
#  </metadata>
#  <defs>
#   <style type="text/css">*{stroke-linejoin: round; stroke-linecap: butt}</style>
#  </defs>
#  <g id="figure_1">
#   <g id="patch_1">
#    <path d="M 0 107.873625  L 124.020625 107.873625  L 124.020625 0  L 0 0  z " style="fill: #e0e0e0"/>
#   </g>
#   <g id="axes_1">
#    <g id="patch_2">
#     <path d="M 32.865625 87.5955  L 102.615625 87.5955  L 102.615625 32.1555  L 32.865625 32.1555  z " style="fill: #ffffff"/>
#    </g>
#    <g id="matplotlib.axis_1">
#     <g id="xtick_1">
#      <g id="line2d_1">
#       <defs>
#        <path id="m3b77e03b1e" d="M 0 0  L 0 3.5  " style="stroke: #000000; stroke-width: 0.8"/>
#       </defs>
#       <g>
#        <use xlink:href="#m3b77e03b1e" x="34.526339" y="87.5955" style="stroke: #000000; stroke-width: 0.8"/>
#       </g>
#      </g>
#      <g id="text_1">
#       <!-- −10.0 -->
#       <g transform="translate(19.203683 102.193937)scale(0.1 -0.1)">
#        <defs>
#         <path id="DejaVuSans-2212" d="M 678 2272  L 4684 2272  L 4684 1741  L 678 1741  L 678 2272  z " transform="scale(0.015625)"/>
#         <path id="DejaVuSans-31" d="M 794 531  L 1825 531  L 1825 4091  L 703 3866  L 703 4441  L 1819 4666  L 2450 4666  L 2450 531  L 3481 531  L 3481 0  L 794 0  L 794 531  z " transform="scale(0.015625)"/>
#         <path id="DejaVuSans-30" d="M 2034 4250  Q 1547 4250 1301 3770  Q 1056 3291 1056 2328  Q 1056 1369 1301 889  Q 1547 409 2034 409  Q 2525 409 2770 889  Q 3016 1369 3016 2328  Q 3016 3291 2770 3770  Q 2525 4250 2034 4250  z M 2034 4750  Q 2819 4750 3233 4129  Q 3647 3509 3647 2328  Q 3647 1150 3233 529  Q 2819 -91 2034 -91  Q 1250 -91 836 529  Q 422 1150 422 2328  Q 422 3509 836 4129  Q 1250 4750 2034 4750  z " transform="scale(0.015625)"/>
#         <path id="DejaVuSans-2e" d="M 684 794  L 1344 794  L 1344 0  L 684 0  L 684 794  z " transform="scale(0.015625)"/>
#        </defs>
#        <use xlink:href="#DejaVuSans-2212"/>
#        <use xlink:href="#DejaVuSans-31" x="83.789062"/>
#        <use xlink:href="#DejaVuSans-30" x="147.412109"/>
#        <use xlink:href="#DejaVuSans-2e" x="211.035156"/>
#        <use xlink:href="#DejaVuSans-30" x="242.822266"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_2">
#      <g id="line2d_2">
#       <g>
#        <use xlink:href="#m3b77e03b1e" x="67.740625" y="87.5955" style="stroke: #000000; stroke-width: 0.8"/>
#       </g>
#      </g>
#      <g id="text_2">
#       <!-- 2.5 -->
#       <g transform="translate(59.789063 102.193937)scale(0.1 -0.1)">
#        <defs>
#         <path id="DejaVuSans-32" d="M 1228 531  L 3431 531  L 3431 0  L 469 0  L 469 531  Q 828 903 1448 1529  Q 2069 2156 2228 2338  Q 2531 2678 2651 2914  Q 2772 3150 2772 3378  Q 2772 3750 2511 3984  Q 2250 4219 1831 4219  Q 1534 4219 1204 4116  Q 875 4013 500 3803  L 500 4441  Q 881 4594 1212 4672  Q 1544 4750 1819 4750  Q 2544 4750 2975 4387  Q 3406 4025 3406 3419  Q 3406 3131 3298 2873  Q 3191 2616 2906 2266  Q 2828 2175 2409 1742  Q 1991 1309 1228 531  z " transform="scale(0.015625)"/>
#         <path id="DejaVuSans-35" d="M 691 4666  L 3169 4666  L 3169 4134  L 1269 4134  L 1269 2991  Q 1406 3038 1543 3061  Q 1681 3084 1819 3084  Q 2600 3084 3056 2656  Q 3513 2228 3513 1497  Q 3513 744 3044 326  Q 2575 -91 1722 -91  Q 1428 -91 1123 -41  Q 819 9 494 109  L 494 744  Q 775 591 1075 516  Q 1375 441 1709 441  Q 2250 441 2565 725  Q 2881 1009 2881 1497  Q 2881 1984 2565 2268  Q 2250 2553 1709 2553  Q 1456 2553 1204 2497  Q 953 2441 691 2322  L 691 4666  z " transform="scale(0.015625)"/>
#        </defs>
#        <use xlink:href="#DejaVuSans-32"/>
#        <use xlink:href="#DejaVuSans-2e" x="63.623047"/>
#        <use xlink:href="#DejaVuSans-35" x="95.410156"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_3">
#      <g id="line2d_3">
#       <g>
#        <use xlink:href="#m3b77e03b1e" x="100.954911" y="87.5955" style="stroke: #000000; stroke-width: 0.8"/>
#       </g>
#      </g>
#      <g id="text_3">
#       <!-- 15.0 -->
#       <g transform="translate(89.822098 102.193937)scale(0.1 -0.1)">
#        <use xlink:href="#DejaVuSans-31"/>
#        <use xlink:href="#DejaVuSans-35" x="63.623047"/>
#        <use xlink:href="#DejaVuSans-2e" x="127.246094"/>
#        <use xlink:href="#DejaVuSans-30" x="159.033203"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_4">
#      <g id="line2d_4">
#       <path d="M 42.829911 87.5955  L 42.829911 32.1555  " clip-path="url(#p87274e7a0e)" style="fill: none; stroke: #b0b0b0; stroke-width: 0.8; stroke-linecap: square"/>
#      </g>
#      <g id="line2d_5">
#       <defs>
#        <path id="m001f3b9e61" d="M 0 0  L 0 4  " style="stroke: #000000; stroke-width: 0.6"/>
#       </defs>
#       <g>
#        <use xlink:href="#m001f3b9e61" x="42.829911" y="87.5955" style="stroke: #000000; stroke-width: 0.6"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_5">
#      <g id="line2d_6">
#       <path d="M 51.133482 87.5955  L 51.133482 32.1555  " clip-path="url(#p87274e7a0e)" style="fill: none; stroke: #b0b0b0; stroke-width: 0.8; stroke-linecap: square"/>
#      </g>
#      <g id="line2d_7">
#       <g>
#        <use xlink:href="#m001f3b9e61" x="51.133482" y="87.5955" style="stroke: #000000; stroke-width: 0.6"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_6">
#      <g id="line2d_8">
#       <path d="M 59.437054 87.5955  L 59.437054 32.1555  " clip-path="url(#p87274e7a0e)" style="fill: none; stroke: #b0b0b0; stroke-width: 0.8; stroke-linecap: square"/>
#      </g>
#      <g id="line2d_9">
#       <g>
#        <use xlink:href="#m001f3b9e61" x="59.437054" y="87.5955" style="stroke: #000000; stroke-width: 0.6"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_7">
#      <g id="line2d_10">
#       <path d="M 76.044196 87.5955  L 76.044196 32.1555  " clip-path="url(#p87274e7a0e)" style="fill: none; stroke: #b0b0b0; stroke-width: 0.8; stroke-linecap: square"/>
#      </g>
#      <g id="line2d_11">
#       <g>
#        <use xlink:href="#m001f3b9e61" x="76.044196" y="87.5955" style="stroke: #000000; stroke-width: 0.6"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_8">
#      <g id="line2d_12">
#       <path d="M 84.347768 87.5955  L 84.347768 32.1555  " clip-path="url(#p87274e7a0e)" style="fill: none; stroke: #b0b0b0; stroke-width: 0.8; stroke-linecap: square"/>
#      </g>
#      <g id="line2d_13">
#       <g>
#        <use xlink:href="#m001f3b9e61" x="84.347768" y="87.5955" style="stroke: #000000; stroke-width: 0.6"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_9">
#      <g id="line2d_14">
#       <path d="M 92.651339 87.5955  L 92.651339
# BN{nodes: 8, arcs: 16, domainSize: 25000, dim: 20285, mem: 199Ko 592o}
# ATE(cstm_slbn) = 1.6897338052619848

# %% [markdown]
# Again, let's evaluate the evolution of the estimated ATE.

# %%
template = custom_s_template

num_obs_list = [5e4, 1e5, 2e5, 4e5]
num_shots = 10
sl_tau_hat_arr = list()

for i in num_obs_list:
    sl_tau_hat_arr.append(list())
    for j in range(num_shots):
        df = generate_lunceford(int(i))

        s_learner = gum.BNLearner(df, template)
        s_learner.useNMLCorrection()
        s_learner.useSmoothingPrior(1e-6)
        s_learner.setSliceOrder([["X3"], ["X1","X2","V1","V2","V3"], ["T"], ["Y"]])
        slbn = s_learner.learnBN()

        sl_tau_hat_arr[-1].append(ATE(slbn))

# %%
plt.boxplot(sl_tau_hat_arr, labels=num_obs_list, meanline=False,
            showmeans=True, showcaps=True)
#plt.axhline(y=2, color='r', linestyle='--', linewidth=1)
plt.title(f"Structure Learning ATE evolution ({num_shots} runs)")
plt.xlabel("Number of observations")
plt.ylabel(r"$\hat{ATE}$")
plt.grid(True)
plt.show()

# %%
covariate_split_list = range(3,10,1)
outcome_split_list = range(50,601,50)

s_grid = np.zeros((len(covariate_split_list), len(outcome_split_list)))

for i in range(len(covariate_split_list)):
    for j in range(len(outcome_split_list)):
        template = getBN(data=df, add_arcs=False,
                         covariate_num_split=covariate_split_list[i],
                         outcome_num_split=outcome_split_list[j])

        s_learner = gum.BNLearner(df, template)
        s_learner.useNMLCorrection()
        s_learner.useSmoothingPrior(1e-6)
        s_learner.setSliceOrder([["X3"], ["X1","X2","V1","V2","V3"], ["T"], ["Y"]])
        bn = s_learner.learnBN()

        ate = ATE(bn)
        s_grid[i][j] = ate

        print(f"{covariate_split_list[i] = }, "\
              f"{outcome_split_list[j] = }, " \
              f"{ate = }")

s_grid[s_grid == 0.0] = None
# Out:
# covariate_split_list[i] = 3, outcome_split_list[j] = 50, ate = 1.161391487026489
# covariate_split_list[i] = 3, outcome_split_list[j] = 100, ate = 1.1624068504724967
# covariate_split_list[i] = 3, outcome_split_list[j] = 150, ate = 1.160677592766561
# covariate_split_list[i] = 3, outcome_split_list[j] = 200, ate = 1.1606077181603243
# covariate_split_list[i] = 3, outcome_split_list[j] = 250, ate = 1.1609481391879923
# covariate_split_list[i] = 3, outcome_split_list[j] = 300, ate = 1.1617579340528856
# covariate_split_list[i] = 3, outcome_split_list[j] = 350, ate = 1.161400014878935
# covariate_split_list[i] = 3, outcome_split_list[j] = 400, ate = 1.160935971507445
# covariate_split_list[i] = 3, outcome_split_list[j] = 450, ate = 1.1617769665522746
# covariate_split_list[i] = 3, outcome_split_list[j] = 500, ate = 1.1615843497888019
# covariate_split_list[i] = 3, outcome_split_list[j] = 550, ate = 1.161396552703287
# covariate_split_list[i] = 3, outcome_split_list[j] = 600, ate = 1.1613797726261597
# covariate_split_list[i] = 4, outcome_split_list[j] = 50, ate = 1.448958786157572
# covariate_split_list[i] = 4, outcome_split_list[j] = 100, ate = 1.447236790630822
# covariate_split_list[i] = 4, outcome_split_list[j] = 150, ate = 1.4482439889798686
# covariate_split_list[i] = 4, outcome_split_list[j] = 200, ate = 0.0
# covariate_split_list[i] = 4, outcome_split_list[j] = 250, ate = 0.0
# covariate_split_list[i] = 4, outcome_split_list[j] = 300, ate = 0.0
# covariate_split_list[i] = 4, outcome_split_list[j] = 350, ate = 0.0
# covariate_split_list[i] = 4, outcome_split_list[j] = 400, ate = 0.0
# covariate_split_list[i] = 4, outcome_split_list[j] = 450, ate = 0.0
# covariate_split_list[i] = 4, outcome_split_list[j] = 500, ate = 0.0
# covariate_split_list[i] = 4, outcome_split_list[j] = 550, ate = 0.0
# covariate_split_list[i] = 4, outcome_split_list[j] = 600, ate = 0.0
# covariate_split_list[i] = 5, outcome_split_list[j] = 50, ate = 1.6010162718691203
# covariate_split_list[i] = 5, outcome_split_list[j] = 100, ate = 1.6003408541626056
# covariate_split_list[i] = 5, outcome_split_list[j] = 150, ate = 1.6026881570998037
# covariate_split_list[i] = 5, outcome_split_list[j] = 200, ate = 1.6150570728247413
# covariate_split_list[i] = 5, outcome_split_list[j] = 250, ate = 1.6143993915997803
# covariate_split_list[i] = 5, outcome_split_list[j] = 300, ate = 0.0
# covariate_split_list[i] = 5, outcome_split_list[j] = 350, ate = 0.0
# covariate_split_list[i] = 5, outcome_split_list[j] = 400, ate = 0.0
# covariate_split_list[i] = 5, outcome_split_list[j] = 450, ate = 0.0
# covariate_split_list[i] = 5, outcome_split_list[j] = 500, ate = 1.6479655393991843
# covariate_split_list[i] = 5, outcome_split_list[j] = 550, ate = 0.0
# covariate_split_list[i] = 5, outcome_split_list[j] = 600, ate = 0.0
# covariate_split_list[i] = 6, outcome_split_list[j] = 50, ate = 1.5771540857042483
# covariate_split_list[i] = 6, outcome_split_list[j] = 100, ate = 1.5767924247641758
# covariate_split_list[i] = 6, outcome_split_list[j] = 150, ate = 1.5759732240482347
# covariate_split_list[i] = 6, outcome_split_list[j] = 200, ate = 1.6190541658564146
# covariate_split_list[i] = 6, outcome_split_list[j] = 250, ate = 1.6170853451793332
# covariate_split_list[i] = 6, outcome_split_list[j] = 300, ate = 0.0
# covariate_split_list[i] = 6, outcome_split_list[j] = 350, ate = 0.0
# covariate_split_list[i] = 6, outcome_split_list[j] = 400, ate = 0.0
# covariate_split_list[i] = 6, outcome_split_list[j] = 450, ate = 0.0
# covariate_split_list[i] = 6, outcome_split_list[j] = 500, ate = 0.0
# covariate_split_list[i] = 6, outcome_split_list[j] = 550, ate = 0.0
# covariate_split_list[i] = 6, outcome_split_list[j] = 600, ate = 0.0
# covariate_split_list[i] = 7, outcome_split_list[j] = 50, ate = 1.5550362828702466
# covariate_split_list[i] = 7, outcome_split_list[j] = 100, ate = 1.5554679359309254
# covariate_split_list[i] = 7, outcome_split_list[j] = 150, ate = 1.554922774664129
# covariate_split_list[i] = 7, outcome_split_list[j] = 200, ate = 1.625005822234302
# covariate_split_list[i] = 7, outcome_split_list[j] = 250, ate = 1.624358881064838
# covariate_split_list[i] = 7, outcome_split_list[j] = 300, ate = 1.6249735864404964
# covariate_split_list[i] = 7, outcome_split_list[j] = 350, ate = 0.0
# covariate_split_list[i] = 7, outcome_split_list[j] = 400, ate = 0.0
# covariate_split_list[i] = 7, outcome_split_list[j] = 450, ate = 0.0
# covariate_split_list[i] = 7, outcome_split_list[j] = 500, ate = 0.0
# covariate_split_list[i] = 7, outcome_split_list[j] = 550, ate = 0.0
# covariate_split_list[i] = 7, outcome_split_list[j] = 600, ate = 0.0
# covariate_split_list[i] = 8, outcome_split_list[j] = 50, ate = 1.5097383495200616
# covariate_split_list[i] = 8, outcome_split_list[j] = 100, ate = 1.5079527967151747
# covariate_split_list[i] = 8, outcome_split_list[j] = 150, ate = 1.5083173512751038
# covariate_split_list[i] = 8, outcome_split_list[j] = 200, ate = 1.5511584060770862
# covariate_split_list[i] = 8, outcome_split_list[j] = 250, ate = 1.550605319617091
# covariate_split_list[i] = 8, outcome_split_list[j] = 300, ate = 1.5511685385779035
# covariate_split_list[i] = 8, outcome_split_list[j] = 350, ate = 0.0
# covariate_split_list[i] = 8, outcome_split_list[j] = 400, ate = 0.0
# covariate_split_list[i] = 8, outcome_split_list[j] = 450, ate = 0.0
# covariate_split_list[i] = 8, outcome_split_list[j] = 500, ate = 0.0
# covariate_split_list[i] = 8, outcome_split_list[j] = 550, ate = 0.0
# covariate_split_list[i] = 8, outcome_split_list[j] = 600, ate = 0.0
# covariate_split_list[i] = 9, outcome_split_list[j] = 50, ate = 1.4941895934294642
# covariate_split_list[i] = 9, outcome_split_list[j] = 100, ate = 1.4948422069171694
# covariate_split_list[i] = 9, outcome_split_list[j] = 150, ate = 1.5443976369892236
# covariate_split_list[i] = 9, outcome_split_list[j] = 200, ate = 1.5446056254300753
# covariate_split_list[i] = 9, outcome_split_list[j] = 250, ate = 1.5438759896445864
# covariate_split_list[i] = 9, outcome_split_list[j] = 300, ate = 1.5448366301932321
# covariate_split_list[i] = 9, outcome_split_list[j] = 350, ate = 0.0
# covariate_split_list[i] = 9, outcome_split_list[j] = 400, ate = 0.0
# covariate_split_list[i] = 9, outcome_split_list[j] = 450, ate = 0.0
# covariate_split_list[i] = 9, outcome_split_list[j] = 500, ate = 0.0
# covariate_split_list[i] = 9, outcome_split_list[j] = 550, ate = 0.0
# covariate_split_list[i] = 9, outcome_split_list[j] = 600, ate = 0.0

# %%
plt.imshow(s_grid)
plt.yticks(np.arange(len(covariate_split_list)), labels=covariate_split_list)
plt.xticks(np.arange(len(outcome_split_list)), labels=outcome_split_list)
plt.colorbar()
plt.xlabel("Outcome number of splits")
plt.ylabel("Covariates number of splits")
plt.title("ATE Estimation")

plt.show()
